# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/flyrank-bih/flyrank-ml-internship-starter/blob/main/work/notebooks/w01_research_question.ipynb)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
#Lane 2: Refresh / Content Opportunity Scoring,
#i choose the lane because the idea of ranking the pages using machine learning helping the companies to save a lot
#of time reviewing and ranking them all and also providing reccomendations to increase the views

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
'''
What decision does your work improve?
This work improves the triage and prioritization process. By ranking pages based on their opportunity for recovery or growth, it provides a data-driven base to decide which pages need content enhancement first.

Who acts on it?
The human content and editorial teams act on this ranked queue by reviewing the top-flagged pages and applying the suitable updates.

What does a wrong recommendation cost?
A wrong recommendation (a false positive) results in a waste of limited editorial time and money. It also carries an opportunity cost, as the team would be busy reviewing a healthy page while missing the chance to fix a page that is actually declining.

'''
# Out:
# '\nWhat decision does your work improve?\nThis work improves the triage and prioritization process. By ranking pages based on their opportunity for recovery or growth, it provides a data-driven base to decide which pages need content enhancement first.\n\nWho acts on it?\nThe human content and editorial teams act on this ranked queue by reviewing the top-flagged pages and applying the suitable updates.\n\nWhat does a wrong recommendation cost?\nA wrong recommendation (a false positive) results in a waste of limited editorial time and money. It also carries an opportunity cost, as the team would be busy reviewing a healthy page while missing the chance to fix a page that is actually declining.\n\n'

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd
import os, sys, subprocess

IN_COLAB = "google.colab" in sys.modules
REPO_URL = "https://github.com/flyrank-bih/flyrank-ml-internship-starter"
REPO_DIR = "flyrank-ml-internship-starter"

if IN_COLAB:
    if not os.path.isdir(REPO_DIR):
        subprocess.run(["git", "clone", "--depth", "1", REPO_URL, REPO_DIR], check=True)
    os.chdir(REPO_DIR)
    subprocess.run([sys.executable, "-m", "pip", "install", "-q", "-r", "requirements.txt"], check=True)
elif os.path.basename(os.getcwd()) == "notebooks":
    os.chdir("..")  # move from notebooks/ to the repo root

print("Working dir:", os.getcwd())
assert os.path.exists("data/raw/content_refresh_anonymized.csv"), "starter CSV not found — are you at the repo root?"
print("Starter data found. You're ready.")
df = pd.read_csv("data/raw/content_refresh_anonymized.csv")
key_columns = [
    "content_id", "impressions_90d", "sessions_90d",
    "content_age_days", "avg_position", "ctr", "trend_direction"
]
# choose these features to check the demand of the pages for the last period
# and to have evidence of movement or an oppurtunity
# to check if teh page is stale
print(df[key_columns].head())
print("\nDataset Shape:", df.shape)
# Out:
# Working dir: /content/flyrank-ml-internship-starter/flyrank-ml-internship-starter/flyrank-ml-internship-starter/flyrank-ml-internship-starter
# Starter data found. You're ready.
#              content_id  impressions_90d  sessions_90d  content_age_days  \
# 0  content_304f48230142             3803            17               187
# 1  content_a1fb4e703a9e            15320             9               445
# 2  content_9aa793d4d895            12581            11               141
# 3  content_331d6c4de07b            11751            78               463
# 4  content_d99b7a2d90ca            19140           145               263
#
#    avg_position   ctr trend_direction
# 0          10.6  0.76            down
# 1          20.3  0.05            down
# 2          36.5  0.09            down
# 3           6.2  0.49          stable
# 4          44.0  0.13            down
#
# Dataset Shape: (30000, 44)

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
#my work will act as a decision-support tool to help prioritize content reviews.
#The insights I provide will be observed and directional, highlighting historical patterns and opportunities.
#I will never claim that this model provides causal proof (e.g., guaranteeing that a specific edit causes a traffic recovery),
# nor will I claim to be predicting Google's algorithm.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
